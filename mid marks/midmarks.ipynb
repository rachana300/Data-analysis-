# %%
import pandas as pd
a=pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
a
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
c=pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
c.shape
# Out:
# (480, 8)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     480 non-null    int64
#  1   SECTION  439 non-null    object
#  2   DV       479 non-null    object
#  3   M-II     477 non-null    object
#  4   PP       480 non-null    object
#  5   BEEE     478 non-null    object
#  6   FL       479 non-null    object
#  7   FIMS     480 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 30.1+ KB

# %%
c.dtypes
# Out:
# S.NO        int64
# SECTION    object
# DV         object
# M-II       object
# PP         object
# BEEE       object
# FL         object
# FIMS       object
# dtype: object

# %%
c.head()
# Out:
#    S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1   ALPHA  12    0  17    9  19   15
# 1     2   ALPHA  19   12  16   16  18    3
# 2     3   ALPHA  18   14  18   18  18   16
# 3     4   ALPHA  15    9  19   17  19   15
# 4     5   ALPHA  18   17  19   19  20   18

# %%
c.rename(columns={'M-II':'m2'},inplace=True)
c
# Out:
#      S.NO SECTION  DV   m2  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
import pandas as pd
c=pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
rows_with_nulls = c[c.isnull().any(axis=1)]
print(rows_with_nulls)
# Out:
#      S.NO  SECTION   DV M-II  PP BEEE   FL FIMS
# 102   103     BETA   10   12  17    9  NaN   16
# 180   181      NaN    9    3   4    2   10   15
# 192   193  EPSILON   16   18  15  NaN   18   18
# 227   228  EPSILON   11  NaN  10   12   10   16
# 323   324    SIGMA    9  NaN   2    3   11    1
# 389   390    OMEGA  NaN   17  17   19   20   17
# 439   440  EPSILON   20   16  20  NaN   20   18
# 440   441      NaN   20   18  20   19   20   18
# 441   442      NaN   20   19  20   19   20   19
# 442   443      NaN   20   11  18   14   20   15
# 443   444      NaN   20   20  20   20   20   16
# 444   445      NaN    5    2  11    0   10   AB
# 445   446      NaN   20    8  19   14   20   13
# 446   447      NaN   20   15  18   16   20   19
# 447   448      NaN   20   12  13   17   20   14
# 448   449      NaN   15    7  14   16   16   16
# 449   450      NaN   20   11  20   13   15   16
# 450   451      NaN    6    3   7   11   11   14
# 451   452      NaN   17    1  11   17   20   19
# ...

# %%
data_cleaned = c.dropna(how='all')
print(data_cleaned)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
import pandas as pd
c=pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
data_cleaned = c.dropna(how='all')
print(data_cleaned)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
c['SECTION'] = c['SECTION'].fillna('SIGMA')
c
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476   SIGMA  18    2  12    3  17   15
# 476   477   SIGMA  20    6  16   11  20   14
# 477   478   SIGMA  20  NaN  18   13  20   18
# 478   479   SIGMA  20   20   5   19  18   14
# 479   480   SIGMA  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
c.rename(columns={'M-II':'m2'},inplace=True)
c
# Out:
#      S.NO SECTION  DV   m2  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476   SIGMA  18    2  12    3  17   15
# 476   477   SIGMA  20    6  16   11  20   14
# 477   478   SIGMA  20  NaN  18   13  20   18
# 478   479   SIGMA  20   20   5   19  18   14
# 479   480   SIGMA  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
data_cleaned = c.dropna(how='all')
print(data_cleaned)
# Out:
#      S.NO SECTION  DV   m2  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476   SIGMA  18    2  12    3  17   15
# 476   477   SIGMA  20    6  16   11  20   14
# 477   478   SIGMA  20  NaN  18   13  20   18
# 478   479   SIGMA  20   20   5   19  18   14
# 479   480   SIGMA  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
import pandas as pd
c=pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
c
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
import pandas as pd
c=pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
rows_with_nulls = [c.isnull().any(axis=1)]
print(rows_with_nulls)
# Out:
# [0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 475     True
# 476     True
# 477     True
# 478     True
# 479     True
# Length: 480, dtype: bool]

# %%
data_cleaned = a.dropna(how='all')
print(data_cleaned)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
c_rounded = c.round(2)
print(c_rounded)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
import pandas as pd

columns_to_convert = ["DV","M-II","PP","BEEE","FL","FIMS"]
for col in columns_to_convert:
 c[col] = pd.to_numeric(c[col], errors='coerce')
 
c["Total"] = c["DV"]+c["M-II"]+c["PP"]+c["BEEE"]+c["FL"]+c["FIMS"]
c
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...
# 475   476     NaN  18.0   2.0  12.0   3.0  17.0  15.0   67.0
# 476   477     NaN  20.0   6.0  16.0  11.0  20.0  14.0   87.0
# 477   478     NaN  20.0   NaN  18.0  13.0  20.0  18.0    NaN
# 478   479     NaN  20.0  20.0   5.0  19.0  18.0  14.0   96.0
# 479   480     NaN  20.0  16.0  18.0  19.0  20.0  19.0  112.0
#
# [480 rows x 9 columns]

# %%
c['Percentage'] = (c['Total'] / 120)*100
c
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage
# 0     60.000000
# 1     70.000000
# 2     85.000000
# 3     78.333333
# 4     92.500000
# ..          ...
# 713   74.166667
# ...

# %%
c_rounded = c.round(2)
 
print(c_rounded)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage
# 0         60.00
# 1         70.00
# 2         85.00
# 3         78.33
# 4         92.50
# ..          ...
# 713       74.17
# ...

# %%
# Grading
def assign_grade(percentage):
    if percentage >= 90:
        return 'A'
    elif percentage >= 80:
        return 'B'
    elif percentage >= 70:
        return 'C'
    elif percentage >= 60:
        return 'D'
    else:
        return 'F'

c['Grade'] = c['Percentage'].apply(assign_grade)
c
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade
# 0     60.000000     D
# 1     70.000000     C
# 2     85.000000     B
# 3     78.333333     C
# 4     92.500000     A
# ...

# %%
 # Group by 'section' and 'grade' columns
grouped_data = c.groupby(['SECTION', 'Grade'])
 # Perform an aggregation, e.g., sum, mean, or count
aggregated_data = grouped_data.sum()  # Replace with .mean(), .count(), etc
 # Display the grouped and aggregated data
print(aggregated_data)
# Out:
#                   S.NO     DV   M-II     PP   BEEE     FL   FIMS    TOTAL  \
# SECTION Grade
# ALPHA   A       1093.0  418.0  426.0  456.0  445.0  450.0  387.0   2186.0
#         B        666.0  250.0  252.0  308.0  295.0  284.0  239.0   1332.0
#         C        603.0  266.0  253.0  322.0  276.0  288.0  223.0   1206.0
#         D        457.0  121.0  107.0  135.0  149.0  143.0  111.0    914.0
#         F       1276.0  152.0  196.0  213.0  241.0  291.0  183.0   2552.0
# BETA    A       1312.0  180.0  187.0  197.0  189.0  198.0  176.0   2624.0
#         B       2190.0  244.0  241.0  283.0  226.0  277.0  245.0   4380.0
#         C       2274.0  223.0  232.0  306.0  188.0  289.0  252.0   4548.0
#         D       2066.0  201.0  197.0  258.0  148.0  240.0  219.0   4132.0
#         F       4353.0  322.0  234.0  393.0  226.0  434.0  372.0   8706.0
# DELTA   A       1709.0  153.0  154.0  154.0  142.0  159.0  154.0   3418.0
# ...

# %%
c.to_csv('MIDMARKS1.csv', index=False)
c
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade
# 0     60.000000     D
# 1     70.000000     C
# 2     85.000000     B
# 3     78.333333     C
# 4     92.500000     A
# ...

# %%
import pandas as pd
data=pd.read_csv("MIDMARKS1.csv")
data
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade
# 0     60.000000     D
# 1     70.000000     C
# 2     85.000000     B
# 3     78.333333     C
# 4     92.500000     A
# ...

# %%
import matplotlib.pyplot as plt
a1=data.groupby('DV')['Total']
a1.hist(color = 'brown',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 0-20 Marks")
plt.xlabel("Total Marks obtained:")
plt.ylabel("Marks in DV")
plt.show()

# %% [markdown]
# Students who got 120 mostly scored in DV

# %%
import matplotlib.pyplot as plt
a1=data.groupby('PP')['Total']
a1.hist(color = 'pink',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 0-20 Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in PP")
plt.show()

# %% [markdown]
# Students who got 80 and above 80 marks were scored more marks in pp

# %%
b=data.loc[(data['Total'] >= 20) & (data['Total'] <= 75)]
b=b.reset_index()
b
# Out:
#      index  S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0        0   1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1       20  21.0   ALPHA   4.0   2.0   5.0   3.0  16.0   9.0   42.0   39.0
# 2       25  26.0   ALPHA   6.0  10.0  10.0  11.0  13.0  10.0   52.0   60.0
# 3       27  28.0   ALPHA   5.0   4.0   3.0  12.0  13.0   5.0   56.0   42.0
# 4       29  30.0   ALPHA   8.0   2.0  11.0  10.0  13.0  12.0   60.0   56.0
# ..     ...   ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 229    700   NaN    ZETA  17.0   7.0   7.0  12.0  13.0   9.0    0.0   65.0
# 230    701   NaN    ZETA  15.0   4.0   3.0  13.0  14.0  13.0    0.0   62.0
# 231    710   NaN    ZETA  18.0   1.0   6.0  12.0  11.0   9.0    0.0   57.0
# 232    714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 233    716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
#
#      Percentage Grade
# 0     60.000000     D
# ...

# %%
b.plot.scatter(x='DV',y='Total',color='green',s=40)
plt.title("20-75 Marks ANALYSIS")
plt.show()

# %% [markdown]
#  Most of the students got 10-12 marks in this analysis

# %%
b.plot.scatter(x='M-II',y='Total',color='purple',s=40)
plt.title("20-75 Marks ANALYSIS")
plt.show()

# %% [markdown]
#  This was the marks analysis of 20-75 marks very less people who got the more score

# %%
b.plot.scatter(x='BEEE',y='Total',color='red',s=40)
plt.title("20-75 Marks ANALYSIS")
plt.show()

# %% [markdown]
# This was the marks analysis of 20-75 marks very less people who got the more score in the
# subject of BEEE

# %%
import pandas as pd
data=pd.read_csv("MIDMARKS1.csv")
data
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade
# 0     60.000000     D
# 1     70.000000     C
# 2     85.000000     B
# 3     78.333333     C
# 4     92.500000     A
# ...

# %%
import matplotlib.pyplot as plt
data.boxplot(by='DV', column =['Total'], grid = False,color='blue')
plt.title("25-75 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
#  This was the boxplot representation which will contains the FIMS marks analysis and most
#  of the students got 20

# %%
data=data.loc[(data['Total']>=25) & (data['Total']<=75)]
data=data.reset_index()
data
# Out:
#      index  S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0        0   1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1       20  21.0   ALPHA   4.0   2.0   5.0   3.0  16.0   9.0   42.0   39.0
# 2       25  26.0   ALPHA   6.0  10.0  10.0  11.0  13.0  10.0   52.0   60.0
# 3       27  28.0   ALPHA   5.0   4.0   3.0  12.0  13.0   5.0   56.0   42.0
# 4       29  30.0   ALPHA   8.0   2.0  11.0  10.0  13.0  12.0   60.0   56.0
# ..     ...   ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 227    700   NaN    ZETA  17.0   7.0   7.0  12.0  13.0   9.0    0.0   65.0
# 228    701   NaN    ZETA  15.0   4.0   3.0  13.0  14.0  13.0    0.0   62.0
# 229    710   NaN    ZETA  18.0   1.0   6.0  12.0  11.0   9.0    0.0   57.0
# 230    714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 231    716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
#
#      Percentage Grade
# 0     60.000000     D
# ...

# %%
data.plot.line(x='DV',y='Total',color='black')
plt.title("Line Graph of DV")
plt.ylabel("Total")
plt.show()

# %% [markdown]
#  This is the line graph of DV subject

# %%
data.plot.line(x='FIMS',y='Total',color='Black')
plt.title("Line Graph of FIMS")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# This is the line graph of FIMS subject

# %%
data['BEEE'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of BEEE")
# Out:
# Text(0.5, 1.0, 'Pie Chart of BEEE')

# %% [markdown]
#  This is the pie chart representation of the BEEE subject

# %%
data.plot()
plt.show()

# %% [markdown]
#  This is the complete data and most of the students got Total was high for above 200

# %%
import pandas as pd
df=pd.read_csv("MIDMARKS1.csv")
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce').fillna(0)
df['Backlogs'] = (df[subjects] < 10).sum(axis=1)
students_with_backlogs = df[df['Backlogs'] > 0]
print(students_with_backlogs[['S.NO', 'SECTION', 'Backlogs']])
total_backlog_students = students_with_backlogs.shape[0]
print(f"Total number of students with backlogs: {total_backlog_students}")
# Out:
#      S.NO SECTION  Backlogs
# 0     1.0   ALPHA         2
# 1     2.0   ALPHA         1
# 3     4.0   ALPHA         1
# 5     6.0   ALPHA         1
# 8     9.0   ALPHA         1
# ..    ...     ...       ...
# 712   NaN    ZETA         1
# 713   NaN    ZETA         2
# 714   NaN    ZETA         3
# 715   NaN    ZETA         1
# 716   NaN    ZETA         3
#
# [445 rows x 3 columns]
# Total number of students with backlogs: 445

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS.csv")
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[subjects] = df[subjects].apply(pd.to_numeric).fillna(0)
failures_per_subject = (df[subjects] < 10).sum()
print("Failures in each subject:")
print(failures_per_subject)
df['Backlogs'] = (df[subjects] < 10).sum(axis=1)
def calculate_result(backlogs):
    if backlogs > 0:
        return 'Fail'
    else:
        return 'Pass'
df['Result'] = df['Backlogs'].apply(calculate_result)
print(df)
# Out:
# Failures in each subject:
# DV       89
# M-II    349
# PP      215
# BEEE    193
# FL       44
# FIMS    120
# dtype: int64
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   12.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   14.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   17.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   15.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   18.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   14.833333
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0    9.666667
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   14.333333
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0    8.833333
# ...

# %%
less_than_10_dv = df[df['DV'] < 10]
less_than_10_dv.SECTION .value_counts()
# Out:
# ALPHA      17
# BETA       17
# DELTA      14
# GAMMA      11
# OMEGA      10
# ZETA        8
# SIGMA       6
# EPSILON     4
# Name: SECTION, dtype: int64

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade  Backlogs
# 0     60.000000     D         2
# 1     70.000000     C         1
# 2     85.000000     B         0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.countplot(x='Backlogs', data=students_with_backlogs, color='green')
plt.title('Distribution of Students by Backlog Count')
plt.xlabel('Number of Backlogs')
plt.ylabel('Number of Students')
plt.show()

# %%
sns.boxplot(x='Backlogs', y='TOTAL', data=df, color='skyblue')  
plt.title('Total Marks by Number of Backlogs')
plt.xlabel('Number of Backlogs')
plt.ylabel('Total Marks')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.histplot(data=students_with_backlogs, x='Backlogs', bins=10, kde=True, color='skyblue')
plt.title('Histogram of Backlogs')
plt.xlabel('Number of Backlogs')
plt.ylabel('Count of Students')  # Changed y-axis label
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Grade", hue="Backlogs", palette="coolwarm")
plt.title("Grade Distribution by Backlogs", fontsize=14)
plt.xlabel("Grade")
plt.ylabel("Count")
plt.legend(title="Backlogs")
plt.show()

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade  Backlogs
# 0     60.000000     D         2
# 1     70.000000     C         1
# 2     85.000000     B         0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("MIDMARKS1.csv")
sns.barplot(x='SECTION', y='Percentage', data=df, palette='coolwarm')
plt.title('Average Percentage by Section')
plt.xlabel('Section')
plt.ylabel('Average Percentage')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
avg_backlogs = df.groupby("Grade")["Backlogs"].mean().reset_index()
sns.barplot(data=avg_backlogs, x="Grade", y="Backlogs", color="blue")  # Set to one color
plt.title("Average Backlogs by Grade", fontsize=14)
plt.xlabel("Grade")
plt.ylabel("Average Number of Backlogs")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("MIDMARKS1.csv")
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce').fillna(0)
df['Backlogs'] = (df[subjects] < 10).sum(axis=1)
students_with_backlogs = df[df['Backlogs'] > 0]
print(students_with_backlogs[['S.NO', 'SECTION', 'Backlogs']])
total_backlogs_students = students_with_backlogs.shape[0]
print(f"Total number of students with baclogs: {total_backlogs_students}")
# Out:
#      S.NO SECTION  Backlogs
# 0     1.0   ALPHA         2
# 1     2.0   ALPHA         1
# 3     4.0   ALPHA         1
# 5     6.0   ALPHA         1
# 8     9.0   ALPHA         1
# ..    ...     ...       ...
# 712   NaN    ZETA         1
# 713   NaN    ZETA         2
# 714   NaN    ZETA         3
# 715   NaN    ZETA         1
# 716   NaN    ZETA         3
#
# [445 rows x 3 columns]
# Total number of students with baclogs: 445

# %%
df['Status']=(df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']]==20).sum(axis=1)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade DV_Grade  Status
# 0     60.000000     D     poor       0
# 1     70.000000     C     good       0
# ...

# %%
df.describe()
# Out:
#              S.NO          DV        M-II          PP        BEEE          FL  \
# count  601.000000  718.000000  718.000000  718.000000  718.000000  718.000000
# mean   301.000000   14.746518    9.922006   12.733983   13.250696   15.501393
# std    173.638033    4.629339    6.610886    5.848171    5.817407    4.544449
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    151.000000   12.000000    4.000000    9.000000    9.000000   13.000000
# 50%    301.000000   16.000000   10.000000   14.000000   15.000000   16.000000
# 75%    451.000000   18.000000   16.000000   18.000000   18.000000   20.000000
# max    601.000000   20.000000   20.000000   20.000000   20.000000   20.000000
#
#              FIMS        TOTAL       Total  Percentage    Backlogs
# count  718.000000   718.000000  682.000000  682.000000  718.000000
# mean    14.008357   503.902507   82.755132   68.962610    1.406685
# ...

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS1.csv")
df.columns = df.columns.str.strip()
def assign_grade(PP):
    if PP >= 20:
        return 'very good'
    elif PP >= 17:
        return 'good'
    elif PP >= 14:
        return 'average'
    else:
        return 'poor'
df['PP_Grade'] = df['PP'].apply(assign_grade)
print(df)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade PP_Grade
# 0     60.000000     D     good
# 1     70.000000     C  average
# 2     85.000000     B     good
# ...

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade PP_Grade
# 0     60.000000     D     good
# 1     70.000000     C  average
# 2     85.000000     B     good
# ...

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS1.csv")
df.columns = df.columns.str.strip()
def assign_grade1(DV):
    if DV >= 20:
        return 'very good'
    elif DV >= 17:
        return 'good'
    elif DV >= 14:
        return 'average'
    else:
        return 'poor'
df['DV_Grade'] = df['DV'].apply(assign_grade1)
print(df)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade DV_Grade
# 0     60.000000     D     poor
# 1     70.000000     C     good
# 2     85.000000     B     good
# ...

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade DV_Grade
# 0     60.000000     D     poor
# 1     70.000000     C     good
# 2     85.000000     B     good
# ...

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS1.csv")
def assign_grade(PP):
    if PP >= 20:
        return 'very good'
    elif PP >= 17:
        return 'good'
    elif PP >= 14:
        return 'average'
    else:
        return 'poor'
df['PP_Grade'] = df['PP'].apply(assign_grade)
print(df)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade PP_Grade
# 0     60.000000     D     good
# 1     70.000000     C  average
# 2     85.000000     B     good
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade PP_Grade
# 0     60.000000     D     good
# 1     70.000000     C  average
# ...

# %%
import pandas as pd
df=pd.read_csv("MIDMARKS1.csv")
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce').fillna(0)
df['Backlogs'] = (df[subjects] < 10).sum(axis=1)
students_with_backlogs = df[df['Backlogs'] > 0]
print(students_with_backlogs[['S.NO', 'SECTION', 'Backlogs']])
total_backlog_students = students_with_backlogs.shape[0]
print(f"Total number of students with backlogs: {total_backlog_students}")
df
# Out:
#      S.NO SECTION  Backlogs
# 0     1.0   ALPHA         2
# 1     2.0   ALPHA         1
# 3     4.0   ALPHA         1
# 5     6.0   ALPHA         1
# 8     9.0   ALPHA         1
# ..    ...     ...       ...
# 712   NaN    ZETA         1
# 713   NaN    ZETA         2
# 714   NaN    ZETA         3
# 715   NaN    ZETA         1
# 716   NaN    ZETA         3
#
# [445 rows x 3 columns]
# Total number of students with backlogs: 445
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# ...

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade DV_Grade
# 0     60.000000     D     poor
# 1     70.000000     C     good
# 2     85.000000     B     good
# ...

# %%
def classify_grade(value):
    if value >= 18:
        return 'A'
    elif value >= 15:
        return 'B'
    elif value >= 10:
        return 'C'
    elif value >= 5:
        return 'D'
    else:
        return 'F'

# %%
import pandas as pd
import matplotlib.pyplot as plt
grade_counts = df['DV'].apply(classify_grade).value_counts()
grade_counts.plot(
    kind='pie',
    figsize=(8, 8),
    autopct='%1.1f%%',
    startangle=90,
    colors=['pink', 'lavender', 'green', 'yellow']
)
plt.title("Distribution of DV Grades")
plt.ylabel('')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.NO        601 non-null    float64
#  1   SECTION     691 non-null    object
#  2   DV          705 non-null    float64
#  3   M-II        704 non-null    float64
#  4   PP          701 non-null    float64
#  5   BEEE        697 non-null    float64
#  6   FL          702 non-null    float64
#  7   FIMS        694 non-null    float64
#  8   TOTAL       718 non-null    float64
#  9   Total       682 non-null    float64
#  10  Percentage  682 non-null    float64
#  11  Grade       718 non-null    object
#  12  DV_Grade    718 non-null    object
# dtypes: float64(10), object(3)
# memory usage: 73.0+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
dv_grade_counts = df['DV_Grade'].value_counts()
print(dv_grade_counts)
# Out:
# poor         229
# good         208
# average      178
# very good    103
# Name: DV_Grade, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

dv_grade_counts = df['DV_Grade'].value_counts()


dv_grade_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    figsize=(6, 6),
    title='DV_Grade Distribution'
)
plt.ylabel('')  
plt.show()

# %%
filtered_grades = dv_grade_counts[['good', 'average']]
filtered_grades.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    figsize=(6, 6),
    title='Filtered DV_Grade Distribution (Good and Average Only)'
)
plt.ylabel('')
plt.show()

# %%
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade PP_Grade
# 0     60.000000     D     good
# 1     70.000000     C  average
# 2     85.000000     B     good
# ...

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS1.csv")
df.columns = df.columns.str.strip()
def assign_grade1(PP):
    if PP >= 20:
        return 'very good'
    elif PP >= 17:
        return 'good'
    elif PP >= 14:
        return 'average'
    else:
        return 'poor'
df['PP_Grade'] = df['PP'].apply(assign_grade1)
print(df)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0    2.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0    4.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0    6.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0    8.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   10.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0    0.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0    0.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0    0.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0    0.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0    0.0  105.0
#
#      Percentage Grade PP_Grade
# 0     60.000000     D     good
# 1     70.000000     C  average
# 2     85.000000     B     good
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
pp_grade_counts = df['PP_Grade'].value_counts()
pp_grade_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    figsize=(6, 6),
    title='Distribution of PP Grades'
)
plt.ylabel('')  
plt.show()

# %%
grouped_data = df.groupby(['SECTION', 'PP_Grade']).size().unstack(fill_value=0)

for section in grouped_data.index:
    grouped_data.loc[section].plot.pie(
        autopct='%1.1f%%',
        startangle=90,
        figsize=(6, 6),
        title=f'Distribution of PP Grades in Section {section}'
    )
    plt.ylabel('')
    plt.show()

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS.csv")
df = df.dropna(how='all')
df['DV'] = pd.to_numeric(df['DV'], errors='coerce').fillna(0)
total_students = len(df)
students_passing_dv = (df['DV'] >= 10).sum()
students_failing_dv = (df['DV'] < 10).sum()
prob_pass_dv = students_passing_dv / total_students
prob_fail_dv = students_failing_dv / total_students
print(f"Total Students: {total_students}")
print(f"Students Passing DV: {students_passing_dv}")
print(f"Students Failing DV: {students_failing_dv}")
print(f"Probability of Passing DV: {prob_pass_dv:.2f}")
print(f"Probability of Failing DV: {prob_fail_dv:.2f}")
# Out:
# Total Students: 718
# Students Passing DV: 629
# Students Failing DV: 89
# Probability of Passing DV: 0.88
# Probability of Failing DV: 0.12

# %%
import pandas as pd

df = pd.read_csv("MIDMARKS.csv")
df = df.dropna(how='all')
df['DV'] = pd.to_numeric(df['DV'], errors='coerce').fillna(0)
df_alpha = df[df['SECTION'].str.contains("ALPHA", na=False)]
total_students_alpha = len(df_alpha)
students_passing_dv_alpha = (df_alpha['DV'] >= 10).sum()
students_failing_dv_alpha = (df_alpha['DV'] < 10).sum()
prob_pass_dv_alpha = students_passing_dv_alpha / total_students_alpha if total_students_alpha > 0 else 0
prob_fail_dv_alpha = students_failing_dv_alpha / total_students_alpha if total_students_alpha > 0 else 0
print(f"Total Students in ALPHA Section: {total_students_alpha}")
print(f"Students Passing DV in ALPHA Section: {students_passing_dv_alpha}")
print(f"Students Failing DV in ALPHA Section: {students_failing_dv_alpha}")
print(f"Probability of Passing DV in ALPHA Section: {prob_pass_dv_alpha:.2f}")
print(f"Probability of Failing DV in ALPHA Section: {prob_fail_dv_alpha:.2f}")
# Out:
# Total Students in ALPHA Section: 90
# Students Passing DV in ALPHA Section: 73
# Students Failing DV in ALPHA Section: 17
# Probability of Passing DV in ALPHA Section: 0.81
# Probability of Failing DV in ALPHA Section: 0.19

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("MIDMARKS.csv")

# Drop rows where all values are NaN
df = df.dropna(how='all')

# Convert all subject columns to numeric (assuming first few columns are non-subject columns)
non_subject_columns = ['SECTION', 'STUDENT_ID', 'NAME']  # Adjust based on actual column names
subject_columns = [col for col in df.columns if col not in non_subject_columns]

# Convert subjects to numeric, filling NaN with 0
df[subject_columns] = df[subject_columns].apply(pd.to_numeric, errors='coerce').fillna(0)

# Get unique sections
sections = df['SECTION'].dropna().unique()

# Process each section
for section in sections:
    print(f"\n===== SECTION: {section} =====")
    df_section = df[df['SECTION'] == section]
    total_students = len(df_section)
    
    for subject in subject_columns:
        passing_count = (df_section[subject] >= 10).sum()
        failing_count = (df_section[subject] < 10).sum()
        
        prob_pass = passing_count / total_students if total_students > 0 else 0
        prob_fail = failing_count / total_students if total_students > 0 else 0
        
        print(f"\nSubject: {subject}")
        print(f"  Total Students: {total_students}")
        print(f"  Students Passing: {passing_count}")
        print(f"  Students Failing: {failing_count}")
        print(f"  Probability of Passing: {prob_pass:.2f}")
        print(f"  Probability of Failing: {prob_fail:.2f}")
# Out:
# ===== SECTION: ALPHA =====
#
# Subject: S.NO
#   Total Students: 90
#   Students Passing: 81
#   Students Failing: 9
#   Probability of Passing: 0.90
#   Probability of Failing: 0.10
#
# Subject: DV
#   Total Students: 90
#   Students Passing: 73
#   Students Failing: 17
#   Probability of Passing: 0.81
#   Probability of Failing: 0.19
#
# Subject: M-II
#   Total Students: 90
#   Students Passing: 72
#   Students Failing: 18
#   Probability of Passing: 0.80
#   Probability of Failing: 0.20
#
# Subject: PP
#   Total Students: 90
#   Students Passing: 78
#   Students Failing: 12
#   Probability of Passing: 0.87
#   Probability of Failing: 0.13
#
# Subject: BEEE
#   Total Students: 90
#   Students Passing: 82
#   Students Failing: 8
#   Probability of Passing: 0.91
#   Probability of Failing: 0.09
#
# Subject: FL
#   Total Students: 90
#   Students Passing: 89
#   Students Failing: 1
#   Probability of Passing: 0.99
#   Probability of Failing: 0.01
#
# Subject: FIMS
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("MIDMARKS.csv")

# Drop rows where all values are NaN
df = df.dropna(how='all')

# Convert all subject columns to numeric (assuming first few columns are non-subject columns)
non_subject_columns = ['SECTION', 'STUDENT_ID', 'NAME']  # Adjust based on actual column names
subject_columns = [col for col in df.columns if col not in non_subject_columns]

# Convert subjects to numeric, filling NaN with 0
df[subject_columns] = df[subject_columns].apply(pd.to_numeric, errors='coerce').fillna(0)

# Get unique sections
sections = df['SECTION'].dropna().unique()

# Process each section
for section in sections:
    print(f"\n===== SECTION: {section} =====")
    df_section = df[df['SECTION'] == section]
    total_students = len(df_section)
    
    for subject in subject_columns:
        passing_count = (df_section[subject] >= 10).sum()
        failing_count = (df_section[subject] < 10).sum()
        
        prob_pass = passing_count / total_students if total_students > 0 else 0
        prob_fail = failing_count / total_students if total_students > 0 else 0
        
        # Calculate the average marks for the subject
        average_marks = df_section[subject].mean()

        print(f"\nSubject: {subject}")
        print(f"  Total Students: {total_students}")
        print(f"  Students Passing: {passing_count}")
        print(f"  Students Failing: {failing_count}")
        print(f"  Probability of Passing: {prob_pass:.2f}")
        print(f"  Probability of Failing: {prob_fail:.2f}")
        print(f"  Average Marks: {average_marks:.2f}")  # Print the average marks

# Calculate overall average for "DV" subject across all sections
if "DV" in subject_columns:
    overall_avg_dv = df["DV"].mean()
    print(f"\n===== OVERALL AVERAGE MARKS IN DV =====")
    print(f"Overall Average Marks in DV: {overall_avg_dv:.2f}")
# Out:
# ===== SECTION: ALPHA =====
#
# Subject: S.NO
#   Total Students: 90
#   Students Passing: 81
#   Students Failing: 9
#   Probability of Passing: 0.90
#   Probability of Failing: 0.10
#   Average Marks: 45.50
#
# Subject: DV
#   Total Students: 90
#   Students Passing: 73
#   Students Failing: 17
#   Probability of Passing: 0.81
#   Probability of Failing: 0.19
#   Average Marks: 13.41
#
# Subject: M-II
#   Total Students: 90
#   Students Passing: 72
#   Students Failing: 18
#   Probability of Passing: 0.80
#   Probability of Failing: 0.20
#   Average Marks: 13.71
#
# Subject: PP
#   Total Students: 90
#   Students Passing: 78
#   Students Failing: 12
#   Probability of Passing: 0.87
#   Probability of Failing: 0.13
#   Average Marks: 15.93
#
# Subject: BEEE
#   Total Students: 90
#   Students Passing: 82
#   Students Failing: 8
#   Probability of Passing: 0.91
#   Probability of Failing: 0.09
#   Average Marks: 15.62
#
# Subject: FL
#   Total Students: 90
#   Students Passing: 89
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("MIDMARKS.csv")

# Drop rows where all values are NaN
df = df.dropna(how='all')

# Define non-subject columns (adjust as needed)
non_subject_columns = ['SECTION', 'STUDENT_ID', 'NAME']  # Adjust based on actual column names
subject_columns = [col for col in df.columns if col not in non_subject_columns]

# Convert subjects to numeric, filling NaN with 0
df[subject_columns] = df[subject_columns].apply(pd.to_numeric, errors='coerce').fillna(0)

# Get unique sections
sections = df['SECTION'].dropna().unique()

# Process each section
for section in sections:
    print(f"\n===== SECTION: {section} =====")
    df_section = df[df['SECTION'] == section]
    total_students = len(df_section)
    
    for subject in subject_columns:
        passing_count = (df_section[subject] >= 10).sum()
        failing_count = (df_section[subject] < 10).sum()
        
        prob_pass = passing_count / total_students if total_students > 0 else 0
        prob_fail = failing_count / total_students if total_students > 0 else 0
        
        # Calculate the average marks for the subject in this section
        average_marks = df_section[subject].mean()

        print(f"\nSubject: {subject}")
        print(f"  Total Students: {total_students}")
        print(f"  Students Passing: {passing_count}")
        print(f"  Students Failing: {failing_count}")
        print(f"  Probability of Passing: {prob_pass:.2f}")
        print(f"  Probability of Failing: {prob_fail:.2f}")
        print(f"  Average Marks in {section}: {average_marks:.2f}")  

# Calculate subject-wise overall averages across all sections
print("\n===== SUBJECT-WISE OVERALL AVERAGES =====")
subject_averages = df[subject_columns].mean()

for subject, avg_marks in subject_averages.items():
    print(f"Overall Average Marks in {subject}: {avg_marks:.2f}")
# Out:
# ===== SECTION: ALPHA =====
#
# Subject: S.NO
#   Total Students: 90
#   Students Passing: 81
#   Students Failing: 9
#   Probability of Passing: 0.90
#   Probability of Failing: 0.10
#   Average Marks in ALPHA: 45.50
#
# Subject: DV
#   Total Students: 90
#   Students Passing: 73
#   Students Failing: 17
#   Probability of Passing: 0.81
#   Probability of Failing: 0.19
#   Average Marks in ALPHA: 13.41
#
# Subject: M-II
#   Total Students: 90
#   Students Passing: 72
#   Students Failing: 18
#   Probability of Passing: 0.80
#   Probability of Failing: 0.20
#   Average Marks in ALPHA: 13.71
#
# Subject: PP
#   Total Students: 90
#   Students Passing: 78
#   Students Failing: 12
#   Probability of Passing: 0.87
#   Probability of Failing: 0.13
#   Average Marks in ALPHA: 15.93
#
# Subject: BEEE
#   Total Students: 90
#   Students Passing: 82
#   Students Failing: 8
#   Probability of Passing: 0.91
#   Probability of Failing: 0.09
#   Average Marks in ALPHA: 15.62
#
# Subject: FL
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("MIDMARKS.csv")

# Drop rows where all values are NaN
df = df.dropna(how='all')

# Define non-subject columns (adjust as needed)
non_subject_columns = ['SECTION', 'STUDENT_ID', 'NAME']  # Adjust based on actual column names
subject_columns = [col for col in df.columns if col not in non_subject_columns]

# Convert subjects to numeric, filling NaN with 0
df[subject_columns] = df[subject_columns].apply(pd.to_numeric, errors='coerce').fillna(0)

# Calculate section-wise averages
section_wise_avg = df.groupby("SECTION")[subject_columns].mean()

# Calculate overall average for all subjects
overall_avg = df[subject_columns].mean().to_frame().T  # Convert to DataFrame

# Add a row label for overall average
overall_avg.index = ["Overall Average"]

# Append the overall average row to the section-wise table
final_table = pd.concat([section_wise_avg, overall_avg])

# Display the table
print("\n===== SUBJECT-WISE AVERAGE MARKS PER SECTION =====")
print(final_table)
# Out:
# ===== SUBJECT-WISE AVERAGE MARKS PER SECTION =====
#                        S.NO         DV       M-II         PP       BEEE  \
# ALPHA             45.500000  13.411111  13.711111  15.933333  15.622222
# BETA             135.500000  13.000000  12.122222  15.966667  10.855556
# DELTA            225.500000  13.866667   9.500000  12.422222   9.455556
# EPSILON          314.500000  15.215909   6.693182   8.568182  14.431818
# GAMMA            403.500000  14.811111   9.288889  10.777778  14.788889
# OMEGA            493.500000  16.555556   8.266667  14.611111  13.522222
# SIGMA            570.000000  15.888889  12.444444  14.301587  13.047619
# ZETA               0.000000  15.255556   7.188889   9.211111  14.433333
# Overall Average  251.951253  14.746518   9.922006  12.733983  13.250696
#
#                         FL       FIMS      TOTAL  PERCENTAGE
# ALPHA            16.177778  12.700000  87.555556   14.592593
# BETA             15.977778  14.044444  81.966667   13.661111
# ...

# %%
import pandas as pd
df = pd.read_csv("MIDMARKS.csv")
df = df.dropna(how='all')
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce').fillna(0)
if 'SECTION' in df.columns:
   
    df['SECTION'] = df['SECTION'].str.strip().str.lower()

    # Function to calculate pass/fail stats for each subject in a section
    def calculate_probabilities(group):
        stats = {'Total Students': len(group)}
        for subject in subjects:
            pass_count = (group[subject] >= 10).sum()
            fail_count = (group[subject] < 10).sum()
            stats[f'{subject} Pass Probability'] = pass_count / len(group)
            stats[f'{subject} Fail Probability'] = fail_count / len(group)
        return pd.Series(stats)

    # Group by Section and apply the function
    section_subject_probabilities = df.groupby('SECTION').apply(calculate_probabilities)

    # Display results
    print(section_subject_probabilities)
else:
    print("No 'SECTION' column found in the dataset.")
# Out:
#          Total Students  DV Pass Probability  DV Fail Probability  \
# SECTION
# alpha              90.0             0.811111             0.188889
# beta               90.0             0.811111             0.188889
# delta              90.0             0.844444             0.155556
# epsilon            88.0             0.954545             0.045455
# gamma              90.0             0.877778             0.122222
# omega              90.0             0.888889             0.111111
# sigma              63.0             0.904762             0.095238
# zeta               90.0             0.911111             0.088889
#
#          M-II Pass Probability  M-II Fail Probability  PP Pass Probability  \
# SECTION
# alpha                 0.800000               0.200000             0.866667
# beta                  0.722222               0.277778             0.911111
# delta                 0.500000               0.500000             0.688889
# ...

# %%
import pandas as pd
k = pd.read_csv("MIDMARKS.csv")
for col in k.columns[2:]:
    k[col] = pd.to_numeric(k[col], errors='coerce')
passing_marks = 10
subject_section_pass = k.groupby('SECTION').apply(lambda df: (df.iloc[:, 2:] >= passing_marks).sum())
subject_section_fail = k.groupby('SECTION').apply(lambda df: (df.iloc[:, 2:] < passing_marks).sum())
total_students_per_section = k.groupby('SECTION').size()
prob_pass = subject_section_pass.div(total_students_per_section, axis=0)
prob_fail = subject_section_fail.div(total_students_per_section, axis=0)
subject_section_pass['Total Pass'] = subject_section_pass.sum(axis=1)
subject_section_fail['Total Fail'] = subject_section_fail.sum(axis=1)
prob_pass['Average Pass Probability'] = prob_pass.mean(axis=1)
prob_fail['Average Fail Probability'] = prob_fail.mean(axis=1)
subject_section_pass.loc['Total'] = subject_section_pass.sum()
subject_section_fail.loc['Total'] = subject_section_fail.sum()
prob_pass.loc['Total'] = prob_pass.mean()
prob_fail.loc['Total'] = prob_fail.mean()
print("Number of students passing each subject in each section with Totals:")
print(subject_section_pass)
print("\nNumber of students failing each subject in each section with Totals:")
print(subject_section_fail)
print("\nProbability of students passing each subject in each section with Averages (0 to 1):")
print(prob_pass)
print("\nProbability of students failing each subject in each section with Averages (0 to 1):")
print(prob_fail)
# Out:
# Number of students passing each subject in each section with Totals:
#           DV  M-II   PP  BEEE   FL  FIMS  TOTAL  PERCENTAGE  Total Pass
# SECTION
# ALPHA     73    72   78    82   89    68     89          79         630
# BETA      73    65   82    49   89    79     90          80         607
# DELTA     76    45   62    44   89    86     89          68         559
# EPSILON   84    24   39    71   80    66     87          64         515
# GAMMA     79    44   54    73   88    67     88          68         561
# OMEGA     80    32   74    69   78    83     86          74         576
# SIGMA     57    43   51    46   60    55     60          52         424
# ZETA      82    27   40    72   75    70     88          67         521
# Total    604   352  480   506  648   574    677         552        4393
#
# Number of students failing each subject in each section with Totals:
#          DV  M-II   PP  BEEE  FL  FIMS  TOTAL  PERCENTAGE  Total Fail
# SECTION
# ...

# %%
df["DV" > 10].value_counts/df.length()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15080\2885819046.py in <module>
# ----> 1 df["DV" > 10].value_counts/df.length()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
DF1 = df["DV"].gt(10).sum() / len(df)
DF2 = df["M-II"].gt(10).sum() / len(df)
DF3 = df["PP"].gt(10).sum() / len(df)
DF4 = df["BEEE"].gt(10).sum() / len(df)
DF5 = df["FL"].gt(10).sum() / len(df)
DF6 = df["FIMS"].gt(10).sum() / len(df)
print("Dv:",DF1)
print("m2:",DF2)
print("PP:",DF3)
print("BEEE:",DF4)
print("FL:",DF5)
print("FIMS:",DF6)
# Out:
# Dv: 0.8398328690807799
# m2: 0.4735376044568245
# PP: 0.6643454038997214
# BEEE: 0.6949860724233984
# FL: 0.8314763231197771
# FIMS: 0.7994428969359332

# %%
a = df[df["SECTION"] == "ALPHA"]["DV"].mean()
print(a)
# Out:
# 13.579545454545455

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 573 entries, 0 to 600
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.NO        573 non-null    int64
#  1   SECTION     573 non-null    object
#  2   DV          573 non-null    float64
#  3   M-II        573 non-null    float64
#  4   PP          573 non-null    float64
#  5   BEEE        573 non-null    float64
#  6   FL          573 non-null    float64
#  7   FIMS        573 non-null    float64
#  8   TOTAL       573 non-null    float64
#  9   PERCENTAGE  573 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 49.2+ KB

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   12.000000
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   14.000000
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   17.000000
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   15.666667
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   18.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 596   569   SIGMA  20.0  20.0  20.0  20.0  20.0  20.0  120.0   20.000000
# 597   570   SIGMA  20.0  20.0  20.0  19.0  19.0  18.0  116.0   19.333333
# 598   571   SIGMA  20.0  20.0  17.0  17.0  19.0  18.0  111.0   18.500000
# 599   572   SIGMA  14.0  12.0  11.0   9.0  18.0  17.0   81.0   13.500000
# 600   573   SIGMA  20.0  19.0  20.0  18.0  18.0  19.0  114.0   19.000000
#
# [573 rows x 10 columns]

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   12.000000
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   14.000000
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   17.000000
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   15.666667
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   18.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 596   569   SIGMA  20.0  20.0  20.0  20.0  20.0  20.0  120.0   20.000000
# 597   570   SIGMA  20.0  20.0  20.0  19.0  19.0  18.0  116.0   19.333333
# 598   571   SIGMA  20.0  20.0  17.0  17.0  19.0  18.0  111.0   18.500000
# 599   572   SIGMA  14.0  12.0  11.0   9.0  18.0  17.0   81.0   13.500000
# 600   573   SIGMA  20.0  19.0  20.0  18.0  18.0  19.0  114.0   19.000000
#
# [573 rows x 10 columns]

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   12.000000
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   14.000000
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   17.000000
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   15.666667
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   18.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 596   569   SIGMA  20.0  20.0  20.0  20.0  20.0  20.0  120.0   20.000000
# 597   570   SIGMA  20.0  20.0  20.0  19.0  19.0  18.0  116.0   19.333333
# 598   571   SIGMA  20.0  20.0  17.0  17.0  19.0  18.0  111.0   18.500000
# 599   572   SIGMA  14.0  12.0  11.0   9.0  18.0  17.0   81.0   13.500000
# 600   573   SIGMA  20.0  19.0  20.0  18.0  18.0  19.0  114.0   19.000000
#
# [573 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 573 entries, 0 to 600
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.NO        573 non-null    int64
#  1   SECTION     573 non-null    object
#  2   DV          573 non-null    float64
#  3   M-II        573 non-null    float64
#  4   PP          573 non-null    float64
#  5   BEEE        573 non-null    float64
#  6   FL          573 non-null    float64
#  7   FIMS        573 non-null    float64
#  8   TOTAL       573 non-null    float64
#  9   PERCENTAGE  573 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 49.2+ KB
